# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading Data

# %%
df = pd.read_excel(r"C:\Users\10-Me22\Downloads\P1-StartupExpansion.xlsx")
df
# Out:
#      Store ID             City       State Sales Region New Expansion  \
# 0           1           Peoria     Arizona     Region 2           Old
# 1           2          Midland       Texas     Region 2           Old
# 2           3          Spokane  Washington     Region 2           Old
# 3           4           Denton       Texas     Region 2           Old
# 4           5    Overland Park      Kansas     Region 2           Old
# ..        ...              ...         ...          ...           ...
# 145       146         Paterson  New Jersey     Region 1           New
# 146       147      Brownsville       Texas     Region 2           New
# 147       148         Rockford    Illinois     Region 1           New
# 148       149  College Station       Texas     Region 2           New
# 149       150    Thousand Oaks  California     Region 2           New
#
#      Marketing Spend  Revenue
# 0               2601    48610
# 1               2727    45689
# 2               2768    49554
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Store ID         150 non-null    int64
#  1   City             150 non-null    object
#  2   State            150 non-null    object
#  3   Sales Region     150 non-null    object
#  4   New Expansion    150 non-null    object
#  5   Marketing Spend  150 non-null    int64
#  6   Revenue          150 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 8.3+ KB

# %%
df.describe()
# Out:
#          Store ID  Marketing Spend       Revenue
# count  150.000000       150.000000    150.000000
# mean    75.500000      2893.146667  39301.433333
# std     43.445368       367.862817  15465.753977
# min      1.000000      1811.000000  15562.000000
# 25%     38.250000      2662.250000  21113.500000
# 50%     75.500000      2898.000000  42993.000000
# 75%    112.750000      3111.500000  51145.500000
# max    150.000000      3984.000000  68828.000000

# %%
df[['Marketing Spend','Revenue']].describe().round(2) 
#mean&median close to each other and have logical relatio with mn&max so we dont have outliers
# Out:
#        Marketing Spend   Revenue
# count           150.00    150.00
# mean           2893.15  39301.43
# std             367.86  15465.75
# min            1811.00  15562.00
# 25%            2662.25  21113.50
# 50%            2898.00  42993.00
# 75%            3111.50  51145.50
# max            3984.00  68828.00

# %% [markdown]
# # Preprossing Data

# %%
df['City'].unique()
# Out:
# array(['Peoria', 'Midland', 'Spokane', 'Denton', 'Overland Park',
#        'Yonkers', 'Birmingham', 'Antioch', 'Worcester', 'Rochester',
#        'Rialto', 'Santa Maria', 'Las Cruces', 'Jackson', 'Hillsboro',
#        'Temecula', 'Tallahassee', 'Fontana', 'Kent', 'Broken Arrow',
#        'Concord', 'Modesto', 'Montgomery', 'Burbank', 'Elk Grove',
#        'Port St. Lucie', 'Elizabeth', 'Salt Lake City', 'Waco', 'Edison',
#        'Boulder', 'Grand Rapids', 'Tyler', 'Charleston', 'Huntsville',
#        'Pearland', 'Inglewood', 'Oxnard', 'Miramar', 'Cape Coral',
#        'Syracuse', 'Newport News', 'Lewisville', 'Carrollton',
#        'San Bernardino', 'Pasadena', 'Roseville', 'Murrieta',
#        'San Angelo', 'Olathe', 'Akron', 'Fullerton', 'Manchester',
#        'Everett', 'West Covina', 'Thornton', 'Hampton', 'Waterbury',
#        'Ventura', 'Davenport', 'Columbia', 'Simi Valley', 'Richmond',
#        'Little Rock', 'El Cajon', 'Santa Clara', 'Oceanside', 'Davie',
# ...

# %%
df['City'].nunique()
# Out:
# 149

# %%
df['City'].value_counts()
#we note that Rochester repeated 2 times so we have to discover whether it is duplication or not
# Out:
# Rochester        2
# Killeen          1
# Wichita Falls    1
# Naperville       1
# Clovis           1
#                 ..
# Akron            1
# Fullerton        1
# Manchester       1
# Everett          1
# Thousand Oaks    1
# Name: City, Length: 149, dtype: int64

# %%
df['State'].unique()
# Out:
# array(['Arizona', 'Texas', 'Washington', 'Kansas', 'New York', 'Alabama',
#        'California', 'Massachusetts', 'New Mexico', 'Mississippi',
#        'Oregon', 'Florida', 'Oklahoma', 'New Jersey', 'Utah', 'Colorado',
#        'Michigan', 'South Carolina', 'Virginia', 'Ohio', 'New Hampshire',
#        'Connecticut', 'Iowa', 'Arkansas', 'Tennessee', 'North Carolina',
#        'Georgia', 'Illinois', 'Montana', 'Indiana', 'South Dakota',
#        'Louisiana', 'Minnesota', 'Wisconsin', 'Rhode Island'],
#       dtype=object)

# %%
df['State'].nunique()
# Out:
# 35

# %%
df['State'].value_counts()
# Out:
# California        40
# Texas             17
# Florida           12
# Washington         7
# Colorado           5
# Illinois           5
# Georgia            4
# Alabama            4
# Connecticut        4
# New Jersey         4
# Arizona            3
# Tennessee          3
# Iowa               3
# Michigan           3
# South Carolina     3
# Utah               3
# Massachusetts      3
# Kansas             3
# New York           3
# Louisiana          2
# North Carolina     2
# Ohio               2
# Virginia           2
# Oregon             2
# Mississippi        1
# New Mexico         1
# Arkansas           1
# New Hampshire      1
# Oklahoma           1
# Montana            1
# Indiana            1
# South Dakota       1
# Minnesota          1
# Wisconsin          1
# Rhode Island       1
# Name: State, dtype: int64

# %%
df['Sales Region'].unique()
# Out:
# array(['Region 2', 'Region 1'], dtype=object)

# %%
df['Sales Region'].value_counts()
# Out:
# Region 2    86
# Region 1    64
# Name: Sales Region, dtype: int64

# %%
df['New Expansion'].unique()
# Out:
# array(['Old', 'New'], dtype=object)

# %%
df['New Expansion'].value_counts()
# Out:
# Old    140
# New     10
# Name: New Expansion, dtype: int64

# %%
df.isna().sum()
# Out:
# Store ID           0
# City               0
# State              0
# Sales Region       0
# New Expansion      0
# Marketing Spend    0
# Revenue            0
# dtype: int64

# %%
df.duplicated().sum() #no row duplication
# Out:
# 0

# %% [markdown]
# # Exploring & Analyzing Data

# %%
df.sample(10)
# Out:
#      Store ID          City           State Sales Region New Expansion  \
# 138       139     Lafayette       Louisiana     Region 1           Old
# 64         65      El Cajon      California     Region 2           Old
# 133       134     Green Bay       Wisconsin     Region 1           Old
# 106       107    South Bend         Indiana     Region 1           Old
# 60         61      Columbia  South Carolina     Region 1           Old
# 37         38        Oxnard      California     Region 2           Old
# 45         46      Pasadena      California     Region 2           Old
# 108       109   Sioux Falls    South Dakota     Region 1           Old
# 112       113     Knoxville       Tennessee     Region 2           Old
# 19         20  Broken Arrow        Oklahoma     Region 2           Old
#
#      Marketing Spend  Revenue
# 138             2603    40255
# 64              2950    19529
# 133             3586    18454
# 106             3005    21953
# 60              2874    42803
# ...

# %% [markdown]
# Main question can be where is the best location to open new stores and which stores we have to close

# %% [markdown]
# First solo column questions

# %%
df['Sales Region'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
df[df['New Expansion']=='New']
# Out:
#      Store ID              City       State Sales Region New Expansion  \
# 140       141       Chattanooga   Tennessee     Region 2           New
# 141       142             Tempe     Arizona     Region 2           New
# 142       143            Joliet    Illinois     Region 1           New
# 143       144  Rancho Cucamonga  California     Region 2           New
# 144       145          Glendale  California     Region 2           New
# 145       146          Paterson  New Jersey     Region 1           New
# 146       147       Brownsville       Texas     Region 2           New
# 147       148          Rockford    Illinois     Region 1           New
# 148       149   College Station       Texas     Region 2           New
# 149       150     Thousand Oaks  California     Region 2           New
#
#      Marketing Spend  Revenue
# 140             3587    55357
# 141             2911    48954
# 142             3279    48315
# 143             2945    52366
# 144             2363    49376
# ...

# %%
df[df['New Expansion']=='Old']
# Out:
#      Store ID           City         State Sales Region New Expansion  \
# 0           1         Peoria       Arizona     Region 2           Old
# 1           2        Midland         Texas     Region 2           Old
# 2           3        Spokane    Washington     Region 2           Old
# 3           4         Denton         Texas     Region 2           Old
# 4           5  Overland Park        Kansas     Region 2           Old
# ..        ...            ...           ...          ...           ...
# 135       136      San Mateo    California     Region 2           Old
# 136       137         Warren      Michigan     Region 1           Old
# 137       138        Norwalk    California     Region 2           Old
# 138       139      Lafayette     Louisiana     Region 1           Old
# 139       140     Providence  Rhode Island     Region 1           Old
#
#      Marketing Spend  Revenue
# 0               2601    48610
# 1               2727    45689
# 2               2768    49554
# ...

# %%
df[df['New Expansion']=='New'].groupby('City').max()['Revenue'].nlargest(10)
# Out:
# City
# Brownsville         63148
# Chattanooga         55357
# Rancho Cucamonga    52366
# Glendale            49376
# Tempe               48954
# Joliet              48315
# Rockford            43377
# Thousand Oaks       40141
# Paterson            34603
# College Station     22457
# Name: Revenue, dtype: int64

# %%
df[df['New Expansion']=='Old'].groupby('City').max()['Revenue'].nlargest(10)
# Out:
# City
# Little Rock       68828
# Grand Rapids      65475
# Rochester         64906
# Oxnard            64302
# Fontana           63027
# Providence        62337
# Birmingham        60338
# Overland Park     59887
# San Bernardino    59870
# Worcester         59840
# Name: Revenue, dtype: int64

# %% [markdown]
# We note that they didn't open new stores depending on highest revenue of old stores

# %%
df[df['New Expansion']=='Old'].groupby('State').sum()['Revenue'].nlargest(10)
# Out:
# C:\Users\10-Me22\AppData\Local\Temp\ipykernel_17272\2653037238.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['New Expansion']=='Old'].groupby('State').sum()['Revenue'].nlargest(10)
# State
# California     1362468
# Texas           554964
# Florida         479023
# Washington      298013
# Alabama         221025
# New York        160046
# Connecticut     158511
# Georgia         157656
# Colorado        156495
# Michigan        147759
# Name: Revenue, dtype: int64

# %%
df[df['New Expansion']=='New'].groupby('State').sum()['Revenue'].nlargest(10)
# Out:
# C:\Users\10-Me22\AppData\Local\Temp\ipykernel_17272\1908139744.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df[df['New Expansion']=='New'].groupby('State').sum()['Revenue'].nlargest(10)
# State
# California    141883
# Illinois       91692
# Texas          85605
# Tennessee      55357
# Arizona        48954
# New Jersey     34603
# Name: Revenue, dtype: int64

# %%
#so now we gonna get ROI = NET PROFIT/INVESTMENT *100
#df['ROI']= round((df['Revenue'] / df['Marketing Spend']) *100 ,2)
#df

# %%
#get profit first to have the actual value of ROI
df['Profit']= df['Revenue'] - df['Marketing Spend']
df
# Out:
#      Store ID             City       State Sales Region New Expansion  \
# 0           1           Peoria     Arizona     Region 2           Old
# 1           2          Midland       Texas     Region 2           Old
# 2           3          Spokane  Washington     Region 2           Old
# 3           4           Denton       Texas     Region 2           Old
# 4           5    Overland Park      Kansas     Region 2           Old
# ..        ...              ...         ...          ...           ...
# 145       146         Paterson  New Jersey     Region 1           New
# 146       147      Brownsville       Texas     Region 2           New
# 147       148         Rockford    Illinois     Region 1           New
# 148       149  College Station       Texas     Region 2           New
# 149       150    Thousand Oaks  California     Region 2           New
#
#      Marketing Spend  Revenue      ROI  Profit
# 0               2601    48610  1868.90   46009
# ...

# %%
#now lets fei the actual return of marketing spent using ROI
df['ROMS'] = round((df['Profit'] / df['Marketing Spend']) *100 ,2)
df['ROMS%'] = df['ROMS'] /100
df
# Out:
#      Store ID             City       State Sales Region New Expansion  \
# 0           1           Peoria     Arizona     Region 2           Old
# 1           2          Midland       Texas     Region 2           Old
# 2           3          Spokane  Washington     Region 2           Old
# 3           4           Denton       Texas     Region 2           Old
# 4           5    Overland Park      Kansas     Region 2           Old
# ..        ...              ...         ...          ...           ...
# 145       146         Paterson  New Jersey     Region 1           New
# 146       147      Brownsville       Texas     Region 2           New
# 147       148         Rockford    Illinois     Region 1           New
# 148       149  College Station       Texas     Region 2           New
# 149       150    Thousand Oaks  California     Region 2           New
#
#      Marketing Spend  Revenue      ROI  Profit     ROMS    ROMS%
# ...

# %%
df.to_csv('startups-modified.csv')
